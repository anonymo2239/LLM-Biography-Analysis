# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
import openai
import random

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
dataset_dir = "C:/Users/aalperen.arda/Documents/GitHub/LLM-Biography-Analysis/main/dataset_new"
output_dir = "C:/Users/aalperen.arda/Documents/GitHub/LLM-Biography-Analysis/main/json_output_new"
os.makedirs(output_dir, exist_ok=True)

# %%
system_prompt = """
Sen bir biyografik bilgi analiz uzmanısın. Sana verilen detaylı metinleri okuyarak, aşağıdaki formatta yapılandırılmış bir JSON çıktısı üretmelisin.

### Görevin:
Metindeki kişiyle ilgili tüm bilgileri analiz et ve aşağıdaki alanlara uygun şekilde JSON nesnesi oluştur. Lütfen bilgileri mümkün olduğunca eksiksiz çıkar. Eksikse `null` veya boş liste olarak belirt.

### JSON formatı:

{
  "ad": "...",                             // kişinin tam adı
  "dogum_yeri": "...",                    // şehir (ve ilçe varsa)
  "dogum_tarihi": "...",                  // gün.ay.yıl (örn: 12.02.1985)
  "yaş": int,                           // örn: 40
  "ilkokul_yılları": "...",               // örn: 1991-1995
  "ilkokul": "...",             
  "lise": "...",
  "lise_yılları": "...",                  // "2008-2010"
  "universite": "...",                    // lisans üniversitesi
  "üniversite_yılları": "...",            // "2008-2010"
  "bolum": "...",                         // lisans bölümü
  "yuksek_lisans": "...",                // üniversite adı
  "yüksek_lisans_yılları": "...",        // "2008-2010"
  "doktora": "...",                      // üniversite adı
  "doktora_yılları": "...",
  "meslegi": "...",                      // diğer bilgilerden mesleğini bul
  "calistigi_kurumlar": ["..."],         // çalıştığı kurum, şirket vs. (birden fazla olabilir)
  "çalışma_başlangıç_yılları": ["liste - her kurum için başlangıç ve bitiş yılı (örn: "2011-2014")"],
  "kurdugu_girisim_ve_dernekler": ["..."], // kurduğu dernekler, STK'lar, şirketler
  "girişim_kuruluş_yılları": ["liste - her girişim için kuruluş yılı"],
  "memleket": "...",                    // doğduğu yer veya anne babasının doğduğu yerler yazılabilir.
  "yasadigi_sehir": "...",
  "hobiler": ["...", "..."],             // metinden çıkarılabilen tüm hobi/ilgi alanları
  "es": "...",
  "cocuklar": ["...", "..."],            // çocuk isimleri
  "akademik_yayinlar": ["..."],          // tezler, projeler, makaleler vs. (başlık olarak)
  "yayın_yılları": ["liste - her yayın için yıl"],
  "dosya_adi": "..."                     // girilen biyografi metnine ait dosya adı (örneğin: ahmet_ermis.md)
}

Lütfen sadece geçerli ve biçimsel olarak doğru bir JSON nesnesi döndür. Açıklama, yorum veya başka metin ekleme. Noktalama ve dizim hatası yapma.

"""

# %%
def chat(message):
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": message}
    ]
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.2
    )
    return response.choices[0].message.content

# %%
for filename in os.listdir(dataset_dir):
    if filename.endswith(".md"):
        with open(os.path.join(dataset_dir, filename), "r", encoding="utf-8") as f:
            metin = f.read()

        try:
            json_output = chat(metin)
            json_path = os.path.join(output_dir, filename.replace(".md", ".json"))
            with open(json_path, "w", encoding="utf-8") as out_f:
                out_f.write(json_output)
            print(f"{filename} -> JSON kaydedildi")
        except Exception as e:
            print(f"{filename} -> HATA: {e}")
# Out:
# ahmet_dogan.md -> JSON kaydedildi
# akin_dogan.md -> JSON kaydedildi
# ali_turkmen.md -> JSON kaydedildi
# alparslan_aydin.md -> JSON kaydedildi
# alperen_aydin.md -> JSON kaydedildi
# alperen_baran.md -> JSON kaydedildi
# alperen_uzun.md -> JSON kaydedildi
# alperen_yilmaz.md -> JSON kaydedildi
# ayhan_korkmaz.md -> JSON kaydedildi
# ayla_cakir.md -> JSON kaydedildi
# ayla_ozdemir.md -> JSON kaydedildi
# ayla_toprak.md -> JSON kaydedildi
# aysegul_keskin.md -> JSON kaydedildi
# aysel_ozturk.md -> JSON kaydedildi
# ayse_cakir.md -> JSON kaydedildi
# aysun_ucar.md -> JSON kaydedildi
# bahar_erdogan.md -> JSON kaydedildi
# baran_keskin.md -> JSON kaydedildi
# batuhan_ozdemir.md -> JSON kaydedildi
# batuhan_ucar.md -> JSON kaydedildi
# baturalp_polat.md -> JSON kaydedildi
# betul_dogan.md -> JSON kaydedildi
# betul_erdogan.md -> JSON kaydedildi
# bulent_yildiz.md -> JSON kaydedildi
# burak_acar.md -> JSON kaydedildi
# burcu_ozsoy.md -> JSON kaydedildi
# burhan_dogan.md -> JSON kaydedildi
# burhan_sezer.md -> JSON kaydedildi
# burhan_turkmen.md -> JSON kaydedildi
# busra_sezer.md -> JSON kaydedildi
# busra_turkmen.md -> JSON kaydedildi
# canan_kaya.md -> JSON kaydedildi
# canan_yilmaz.md -> JSON kaydedildi
# cansu_acar.md -> JSON kaydedildi
# can_ucar.md -> JSON kaydedildi
# cemre_ozkan.md -> JSON kaydedildi
# cem_simsek.md -> JSON kaydedildi
# ceren_yilmaz.md -> JSON kaydedildi
# ceyda_dogan.md -> JSON kaydedildi
# cihan_aktas.md -> JSON kaydedildi
# derya_avci.md -> JSON kaydedildi
# derya_celik.md -> JSON kaydedildi
# dogukan_ermis.md -> JSON kaydedildi
# duygu_ergin.md -> JSON kaydedildi
# duygu_ozkan.md -> JSON kaydedildi
# ebru_avci.md -> JSON kaydedildi
# ebru_kurt.md -> JSON kaydedildi
# eda_altun.md -> JSON kaydedildi
# ekin_eren.md -> JSON kaydedildi
# ekin_kara.md -> JSON kaydedildi
# elif_gunes.md -> JSON kaydedildi
# elif_keskin.md -> JSON kaydedildi
# elif_yalcin.md -> JSON kaydedildi
# elvan_cakir.md -> JSON kaydedildi
# emrah_baran.md -> JSON kaydedildi
# emre_polat.md -> JSON kaydedildi
# engin_tan.md -> JSON kaydedildi
# ercan_yilmaz.md -> JSON kaydedildi
# erhan_keskin.md -> JSON kaydedildi
# faruk_keskin.md -> JSON kaydedildi
# faruk_korkmaz.md -> JSON kaydedildi
# fatma_ozkan.md -> JSON kaydedildi
# ferhat_kurt.md -> JSON kaydedildi
# fidan_dogan.md -> JSON kaydedildi
# fikri_bulut.md -> JSON kaydedildi
# fikri_polat.md -> JSON kaydedildi
# fuat_bulut.md -> JSON kaydedildi
# gokhan_arslan.md -> JSON kaydedildi
# gokhan_cakir.md -> JSON kaydedildi
# gokhan_ozsoy.md -> JSON kaydedildi
# gokhan_tan.md -> JSON kaydedildi
# gokhan_toprak.md -> JSON kaydedildi
# gulay_aktas.md -> JSON kaydedildi
# gulay_sezer.md -> JSON kaydedildi
# gulay_uzun.md -> JSON kaydedildi
# gulben_kara.md -> JSON kaydedildi
# gulcin_polat.md -> JSON kaydedildi
# gulnur_toprak.md -> JSON kaydedildi
# gulnur_yildiz.md -> JSON kaydedildi
# gul_baran.md -> JSON kaydedildi
# gul_yildirim.md -> JSON kaydedildi
# hakan_simsek.md -> JSON kaydedildi
# halit_aktas.md -> JSON kaydedildi
# halit_baran.md -> JSON kaydedildi
# haluk_bulut.md -> JSON kaydedildi
# haluk_erdogan.md -> JSON kaydedildi
# hande_aslan.md -> JSON kaydedildi
# hande_aydin.md -> JSON kaydedildi
# hande_kaplan.md -> JSON kaydedildi
# harun_koc.md -> JSON kaydedildi
# harun_tas.md -> JSON kaydedildi
# hasan_aksoy.md -> JSON kaydedildi
# hasan_bozkurt.md -> JSON kaydedildi
# hasan_guler.md -> JSON kaydedildi
# hatice_eren.md -> JSON kaydedildi
# hatice_polat.md -> JSON kaydedildi
# humeyra_guler.md -> JSON kaydedildi
# husnu_aktas.md -> JSON kaydedildi
# husnu_guler.md -> JSON kaydedildi
# husnu_kurt.md -> JSON kaydedildi
# i̇brahim_can.md -> JSON kaydedildi
# i̇brahim_sezer.md -> JSON kaydedildi
# i̇kra_demir.md -> JSON kaydedildi
# i̇kra_sahin.md -> JSON kaydedildi
# i̇pek_aksoy.md -> JSON kaydedildi
# i̇pek_gunes.md -> JSON kaydedildi
# i̇rem_can.md -> JSON kaydedildi
# i̇rem_polat.md -> JSON kaydedildi
# i̇rem_yalcin.md -> JSON kaydedildi
# i̇skender_aksoy.md -> JSON kaydedildi
# i̇skender_cakir.md -> JSON kaydedildi
# i̇skender_kara.md -> JSON kaydedildi
# i̇smail_aktas.md -> JSON kaydedildi
# i̇smail_eren.md -> JSON kaydedildi
# i̇smail_gunes.md -> JSON kaydedildi
# i̇smail_ucar.md -> JSON kaydedildi
# i̇zzet_arslan.md -> JSON kaydedildi
# i̇zzet_ozkan.md -> JSON kaydedildi
# i̇zzet_yalcin.md -> JSON kaydedildi
# i̇zzet_yildiz.md -> JSON kaydedildi
# kaan_arslan.md -> JSON kaydedildi
# kaan_baran.md -> JSON kaydedildi
# kaan_gunes.md -> JSON kaydedildi
# kaan_ozdemir.md -> JSON kaydedildi
# kaan_yilmaz.md -> JSON kaydedildi
# kadir_altun.md -> JSON kaydedildi
# kemal_can.md -> JSON kaydedildi
# levent_ermis.md -> JSON kaydedildi
# mahir_koc.md -> JSON kaydedildi
# mahmut_aksoy.md -> JSON kaydedildi
# mahmut_karaca.md -> JSON kaydedildi
# melek_aksoy.md -> JSON kaydedildi
# melek_eren.md -> JSON kaydedildi
# melek_ermis.md -> JSON kaydedildi
# melek_yilmaz.md -> JSON kaydedildi
# melis_demir.md -> JSON kaydedildi
# meltem_altun.md -> JSON kaydedildi
# meltem_eren.md -> JSON kaydedildi
# meltem_karaca.md -> JSON kaydedildi
# mert_cakir.md -> JSON kaydedildi
# mert_ozturk.md -> JSON kaydedildi
# mert_turkmen.md -> JSON kaydedildi
# meryem_ergin.md -> JSON kaydedildi
# meryem_tan.md -> JSON kaydedildi
# nazan_kaplan.md -> JSON kaydedildi
# nazan_kaya.md -> JSON kaydedildi
# nazan_turkmen.md -> JSON kaydedildi
# necati_aslan.md -> JSON kaydedildi
# necati_baran.md -> JSON kaydedildi
# necati_ozturk.md -> JSON kaydedildi
# necla_gunes.md -> JSON kaydedildi
# nefise_aksoy.md -> JSON kaydedildi
# nefise_aydin.md -> JSON kaydedildi
# nese_demir.md -> JSON kaydedildi
# nihat_keskin.md -> JSON kaydedildi
# nihat_simsek.md -> JSON kaydedildi
# nisan_aktas.md -> JSON kaydedildi
# nisan_cakir.md -> JSON kaydedildi
# omer_ermis.md -> JSON kaydedildi
# onur_aslan.md -> JSON kaydedildi
# onur_kaya.md -> JSON kaydedildi
# orhan_gokmen.md -> JSON kaydedildi
# ozan_altun.md -> JSON kaydedildi
# ozan_aslan.md -> JSON kaydedildi
# ozan_dogan.md -> JSON kaydedildi
# ozan_tan.md -> JSON kaydedildi
# ozge_karaca.md -> JSON kaydedildi
# ozge_simsek.md -> JSON kaydedildi
# ozge_yildiz.md -> JSON kaydedildi
# ozgur_bulut.md -> JSON kaydedildi
# ozgur_ozsoy.md -> JSON kaydedildi
# ozgur_simsek.md -> JSON kaydedildi
# ramazan_kaplan.md -> JSON kaydedildi
# ramazan_yuce.md -> JSON kaydedildi
# resat_simsek.md -> JSON kaydedildi
# riza_erdogan.md -> JSON kaydedildi
# rukiye_aslan.md -> JSON kaydedildi
# sahin_guler.md -> JSON kaydedildi
# sahin_yildiz.md -> JSON kaydedildi
# salih_demir.md -> JSON kaydedildi
# salih_ergin.md -> JSON kaydedildi
# salih_kara.md -> JSON kaydedildi
# salih_polat.md -> JSON kaydedildi
# sami_simsek.md -> JSON kaydedildi
# sami_yildiz.md -> JSON kaydedildi
# sebnem_ozsoy.md -> JSON kaydedildi
# sedef_sezer.md -> JSON kaydedildi
# selin_acar.md -> JSON kaydedildi
# semra_eren.md -> JSON kaydedildi
# semra_turkmen.md -> JSON kaydedildi
# serap_arslan.md -> JSON kaydedildi
# serpil_ergin.md -> JSON kaydedildi
# serra_cakir.md -> JSON kaydedildi
# sevda_toprak.md -> JSON kaydedildi
# sevda_yildirim.md -> JSON kaydedildi
# seyma_eren.md -> JSON kaydedildi
# seyma_gunes.md -> JSON kaydedildi
# sinan_gunes.md -> JSON kaydedildi
# sinan_sezer.md -> JSON kaydedildi
# sinan_yalcin.md -> JSON kaydedildi
# sirin_altun.md -> JSON kaydedildi
# sirin_bozkurt.md -> JSON kaydedildi
# sirin_can.md -> JSON kaydedildi
# sirin_erdogan.md -> JSON kaydedildi
# suheyla_ozsoy.md -> JSON kaydedildi
# suleyman_cakir.md -> JSON kaydedildi
# suleyman_eren.md -> JSON kaydedildi
# suleyman_kaplan.md -> JSON kaydedildi
# suleyman_kara.md -> JSON kaydedildi
# suleyman_ozkan.md -> JSON kaydedildi
# suna_tas.md -> JSON kaydedildi
# taner_ozturk.md -> JSON kaydedildi
# tarik_aktas.md -> JSON kaydedildi
# tarik_ucar.md -> JSON kaydedildi
# tugba_aydin.md -> JSON kaydedildi
# ugur_aydin.md -> JSON kaydedildi
# ugur_simsek.md -> JSON kaydedildi
# vedat_ozturk.md -> JSON kaydedildi
# vedat_sezer.md -> JSON kaydedildi
# vedat_tan.md -> JSON kaydedildi
# veli_arslan.md -> JSON kaydedildi
# veli_tas.md -> JSON kaydedildi
# vildan_guler.md -> JSON kaydedildi
# vildan_yilmaz.md -> JSON kaydedildi
# yasemin_sezer.md -> JSON kaydedildi
# yeliz_kaya.md -> JSON kaydedildi
# yeliz_yildiz.md -> JSON kaydedildi
# yilmaz_erdogan.md -> JSON kaydedildi
# yunus_karaca.md -> JSON kaydedildi
# yunus_yilmaz.md -> JSON kaydedildi
# yusuf_bulut.md -> JSON kaydedildi
# zafer_bozkurt.md -> JSON kaydedildi
# zafer_can.md -> JSON kaydedildi
# zehra_ermis.md -> JSON kaydedildi
# zeki_altun.md -> JSON kaydedildi
# zeki_avci.md -> JSON kaydedildi
# zeki_toprak.md -> JSON kaydedildi
# zeynep_avci.md -> JSON kaydedildi
# zeynep_celik.md -> JSON kaydedildi
# zeynep_demir.md -> JSON kaydedildi
# zeynep_ozsoy.md -> JSON kaydedildi
# zeynep_uzun.md -> JSON kaydedildi
# zeynep_yilmaz.md -> JSON kaydedildi

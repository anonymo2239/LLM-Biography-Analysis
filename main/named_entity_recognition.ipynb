# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
import openai
import random

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
dataset_dir = "C:/Users/aalperen.arda/Documents/GitHub/LLM-Biography-Analysis/main/dataset"
output_dir = "C:/Users/aalperen.arda/Documents/GitHub/LLM-Biography-Analysis/main/json_output"
os.makedirs(output_dir, exist_ok=True)

# %%
system_prompt = """
Sen bir biyografik bilgi analiz uzmanısın. Sana verilen detaylı metinleri okuyarak, aşağıdaki formatta yapılandırılmış bir JSON çıktısı üretmelisin.

### Görevin:
Metindeki kişiyle ilgili tüm bilgileri analiz et ve aşağıdaki alanlara uygun şekilde JSON nesnesi oluştur. Lütfen bilgileri mümkün olduğunca eksiksiz çıkar. Eksikse `null` veya boş liste olarak belirt.

### JSON formatı:

{
  "ad": "...",                             // kişinin tam adı
  "dogum_yeri": "...",                    // şehir (ve ilçe varsa)
  "dogum_tarihi": "...",                  // gün.ay.yıl (örn: 12.02.1985)
  "ilkokul": "...",
  "lise": "...",
  "universite": "...",                    // lisans üniversitesi
  "bolum": "...",                         // lisans bölümü
  "yuksek_lisans": "...",                // üniversite adı
  "doktora": "...",                      // üniversite adı
  "calistigi_kurumlar": ["..."],         // çalıştığı kurum, şirket vs. (birden fazla olabilir)
  "kurdugu_girisim_ve_dernekler": ["..."], // kurduğu dernekler, STK'lar, şirketler
  "yasadigi_sehir": "...",
  "hobiler": ["...", "..."],             // metinden çıkarılabilen tüm hobi/ilgi alanları
  "es": "...",
  "cocuklar": ["...", "..."],            // çocuk isimleri
  "akademik_yayinlar": ["..."],          // tezler, projeler, makaleler vs. (başlık olarak)
  "dosya_adi": "..."                     // girilen biyografi metnine ait dosya adı (örneğin: ahmet_ermis.md)
}

Lütfen sadece geçerli ve biçimsel olarak doğru bir JSON nesnesi döndür. Açıklama, yorum veya başka metin ekleme. Noktalama ve dizim hatası yapma.

"""

# %%
def chat(message):
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": message}
    ]
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.2
    )
    return response.choices[0].message.content

# %%
for filename in os.listdir(dataset_dir):
    if filename.endswith(".md"):
        with open(os.path.join(dataset_dir, filename), "r", encoding="utf-8") as f:
            metin = f.read()

        try:
            json_output = chat(metin)
            json_path = os.path.join(output_dir, filename.replace(".md", ".json"))
            with open(json_path, "w", encoding="utf-8") as out_f:
                out_f.write(json_output)
            print(f"{filename} -> JSON kaydedildi")
        except Exception as e:
            print(f"{filename} -> HATA: {e}")
# Out:
# ahmet_ermis.md -> JSON kaydedildi
# ahmet_tan.md -> JSON kaydedildi
# ahmet_yildiz.md -> JSON kaydedildi
# akin_korkmaz.md -> JSON kaydedildi
# ali_polat.md -> JSON kaydedildi
# alparslan_yuce.md -> JSON kaydedildi
# alperen_demir.md -> JSON kaydedildi
# alperen_gokmen.md -> JSON kaydedildi
# alperen_toprak.md -> JSON kaydedildi
# alper_yildiz.md -> JSON kaydedildi
# arif_gunes.md -> JSON kaydedildi
# asli_gokmen.md -> JSON kaydedildi
# asli_tas.md -> JSON kaydedildi
# asli_ucar.md -> JSON kaydedildi
# asude_aktas.md -> JSON kaydedildi
# asude_altun.md -> JSON kaydedildi
# asuman_celik.md -> JSON kaydedildi
# ayhan_ozkan.md -> JSON kaydedildi
# aylin_tas.md -> JSON kaydedildi
# aysegul_aktas.md -> JSON kaydedildi
# aysegul_uzun.md -> JSON kaydedildi
# aysel_gunes.md -> JSON kaydedildi
# ayse_arslan.md -> JSON kaydedildi
# aysun_ozturk.md -> JSON kaydedildi
# aysun_polat.md -> JSON kaydedildi
# aysun_uzun.md -> JSON kaydedildi
# aysun_yildirim.md -> JSON kaydedildi
# bahar_ozkan.md -> JSON kaydedildi
# bahar_sezer.md -> JSON kaydedildi
# baran_avci.md -> JSON kaydedildi
# baran_dogan.md -> JSON kaydedildi
# baran_yuce.md -> JSON kaydedildi
# batuhan_gokmen.md -> JSON kaydedildi
# batuhan_karaca.md -> JSON kaydedildi
# batuhan_sezer.md -> JSON kaydedildi
# baturalp_baran.md -> JSON kaydedildi
# baturalp_can.md -> JSON kaydedildi
# baturalp_kaplan.md -> JSON kaydedildi
# beren_kaplan.md -> JSON kaydedildi
# beren_sezer.md -> JSON kaydedildi
# berk_aydin.md -> JSON kaydedildi
# bora_bulut.md -> JSON kaydedildi
# bora_celik.md -> JSON kaydedildi
# bulent_demir.md -> JSON kaydedildi
# bulent_keskin.md -> JSON kaydedildi
# burak_aslan.md -> JSON kaydedildi
# burak_kara.md -> JSON kaydedildi
# burhan_yildiz.md -> JSON kaydedildi
# busra_altun.md -> JSON kaydedildi
# busra_kaya.md -> JSON kaydedildi
# busra_turkmen.md -> JSON kaydedildi
# canan_aktas.md -> JSON kaydedildi
# canan_can.md -> JSON kaydedildi
# canan_dogan.md -> JSON kaydedildi
# canan_yalcin.md -> JSON kaydedildi
# cansu_gunes.md -> JSON kaydedildi
# cemre_avci.md -> JSON kaydedildi
# cem_simsek.md -> JSON kaydedildi
# cengiz_aktas.md -> JSON kaydedildi
# ceren_keskin.md -> JSON kaydedildi
# ceyda_yilmaz.md -> JSON kaydedildi
# demet_arslan.md -> JSON kaydedildi
# demet_kurt.md -> JSON kaydedildi
# derya_keskin.md -> JSON kaydedildi
# derya_yilmaz.md -> JSON kaydedildi
# duygu_uzun.md -> JSON kaydedildi
# eda_celik.md -> JSON kaydedildi
# eda_turkmen.md -> JSON kaydedildi
# ekin_demir.md -> JSON kaydedildi
# ekin_ozdemir.md -> JSON kaydedildi
# elif_baran.md -> JSON kaydedildi
# elif_guler.md -> JSON kaydedildi
# elif_karaca.md -> JSON kaydedildi
# elif_sezer.md -> JSON kaydedildi
# elif_tas.md -> JSON kaydedildi
# elif_turkmen.md -> JSON kaydedildi
# elif_yuce.md -> JSON kaydedildi
# elvan_ozsoy.md -> JSON kaydedildi
# elvan_yalcin.md -> JSON kaydedildi
# elvan_yildirim.md -> JSON kaydedildi
# emrah_aktas.md -> JSON kaydedildi
# emrah_bozkurt.md -> JSON kaydedildi
# emrah_yilmaz.md -> JSON kaydedildi
# engin_yalcin.md -> JSON kaydedildi
# ercan_aydin.md -> JSON kaydedildi
# erdal_kaplan.md -> JSON kaydedildi
# erhan_altun.md -> JSON kaydedildi
# erhan_eren.md -> JSON kaydedildi
# fatma_can.md -> JSON kaydedildi
# fatma_tan.md -> JSON kaydedildi
# ferhat_altun.md -> JSON kaydedildi
# ferhat_guler.md -> JSON kaydedildi
# ferhat_kara.md -> JSON kaydedildi
# ferhat_ucar.md -> JSON kaydedildi
# fikret_bozkurt.md -> JSON kaydedildi
# fikret_cakir.md -> JSON kaydedildi
# fikret_tas.md -> JSON kaydedildi
# fikri_aslan.md -> JSON kaydedildi
# fuat_aydin.md -> JSON kaydedildi
# fuat_ozsoy.md -> JSON kaydedildi
# gokhan_ozkan.md -> JSON kaydedildi
# gokhan_ozsoy.md -> JSON kaydedildi
# gulay_dogan.md -> JSON kaydedildi
# gulcin_aslan.md -> JSON kaydedildi
# gulcin_korkmaz.md -> JSON kaydedildi
# gulcin_ozdemir.md -> JSON kaydedildi
# gulnur_ozdemir.md -> JSON kaydedildi
# gulsum_gunes.md -> JSON kaydedildi
# gul_altun.md -> JSON kaydedildi
# gul_demir.md -> JSON kaydedildi
# gul_yalcin.md -> JSON kaydedildi
# hakan_kaya.md -> JSON kaydedildi
# hakan_ucar.md -> JSON kaydedildi
# halit_simsek.md -> JSON kaydedildi
# haluk_toprak.md -> JSON kaydedildi
# haluk_yalcin.md -> JSON kaydedildi
# hande_aksoy.md -> JSON kaydedildi
# hande_gunes.md -> JSON kaydedildi
# harun_toprak.md -> JSON kaydedildi
# hatice_altun.md -> JSON kaydedildi
# hava_altun.md -> JSON kaydedildi
# hava_celik.md -> JSON kaydedildi
# hidayet_bozkurt.md -> JSON kaydedildi
# hidayet_erdogan.md -> JSON kaydedildi
# hidayet_yildirim.md -> JSON kaydedildi
# hulya_baran.md -> JSON kaydedildi
# hulya_simsek.md -> JSON kaydedildi
# hulya_yildiz.md -> JSON kaydedildi
# humeyra_celik.md -> JSON kaydedildi
# huseyin_celik.md -> JSON kaydedildi
# huseyin_erdogan.md -> JSON kaydedildi
# huseyin_kaya.md -> JSON kaydedildi
# huseyin_yildiz.md -> JSON kaydedildi
# i̇brahim_aslan.md -> JSON kaydedildi
# i̇pek_kaplan.md -> JSON kaydedildi
# i̇rem_gunes.md -> JSON kaydedildi
# i̇skender_aydin.md -> JSON kaydedildi
# i̇smail_gokmen.md -> JSON kaydedildi
# i̇smail_ozdemir.md -> JSON kaydedildi
# i̇smail_simsek.md -> JSON kaydedildi
# i̇zzet_tas.md -> JSON kaydedildi
# kaan_kara.md -> JSON kaydedildi
# kaan_kurt.md -> JSON kaydedildi
# kadir_can.md -> JSON kaydedildi
# kadir_guler.md -> JSON kaydedildi
# kadir_karaca.md -> JSON kaydedildi
# kadir_koc.md -> JSON kaydedildi
# kubra_ozdemir.md -> JSON kaydedildi
# kubra_ozkan.md -> JSON kaydedildi
# kubra_ozturk.md -> JSON kaydedildi
# kubra_toprak.md -> JSON kaydedildi
# levent_celik.md -> JSON kaydedildi
# levent_yildirim.md -> JSON kaydedildi
# mahir_acar.md -> JSON kaydedildi
# mahir_dogan.md -> JSON kaydedildi
# mahmut_baran.md -> JSON kaydedildi
# mahmut_demir.md -> JSON kaydedildi
# mahmut_ucar.md -> JSON kaydedildi
# melek_aktas.md -> JSON kaydedildi
# melek_dogan.md -> JSON kaydedildi
# melek_ermis.md -> JSON kaydedildi
# melek_turkmen.md -> JSON kaydedildi
# meltem_acar.md -> JSON kaydedildi
# meltem_altun.md -> JSON kaydedildi
# meltem_ergin.md -> JSON kaydedildi
# meltem_karaca.md -> JSON kaydedildi
# mert_ergin.md -> JSON kaydedildi
# mert_toprak.md -> JSON kaydedildi
# merve_can.md -> JSON kaydedildi
# merve_korkmaz.md -> JSON kaydedildi
# murat_simsek.md -> JSON kaydedildi
# mustafa_aksoy.md -> JSON kaydedildi
# nazan_aktas.md -> JSON kaydedildi
# nazan_aslan.md -> JSON kaydedildi
# nazan_bulut.md -> JSON kaydedildi
# nazan_kaplan.md -> JSON kaydedildi
# nazan_sahin.md -> JSON kaydedildi
# nazli_arslan.md -> JSON kaydedildi
# nazli_sahin.md -> JSON kaydedildi
# necati_bozkurt.md -> JSON kaydedildi
# necati_gokmen.md -> JSON kaydedildi
# necati_ozkan.md -> JSON kaydedildi
# necati_yildirim.md -> JSON kaydedildi
# necla_dogan.md -> JSON kaydedildi
# nefise_baran.md -> JSON kaydedildi
# nefise_guler.md -> JSON kaydedildi
# nefise_ozkan.md -> JSON kaydedildi
# nefise_simsek.md -> JSON kaydedildi
# nese_keskin.md -> JSON kaydedildi
# nese_ozkan.md -> JSON kaydedildi
# neslihan_can.md -> JSON kaydedildi
# nihat_arslan.md -> JSON kaydedildi
# nisan_dogan.md -> JSON kaydedildi
# nisan_eren.md -> JSON kaydedildi
# okan_gokmen.md -> JSON kaydedildi
# omer_eren.md -> JSON kaydedildi
# omer_kurt.md -> JSON kaydedildi
# omer_ozturk.md -> JSON kaydedildi
# orhan_avci.md -> JSON kaydedildi
# orhan_cakir.md -> JSON kaydedildi
# orhan_can.md -> JSON kaydedildi
# orhan_ergin.md -> JSON kaydedildi
# orhan_guler.md -> JSON kaydedildi
# orhan_karaca.md -> JSON kaydedildi
# orhan_ucar.md -> JSON kaydedildi
# ozge_can.md -> JSON kaydedildi
# ozge_kurt.md -> JSON kaydedildi
# ozge_sahin.md -> JSON kaydedildi
# ozgur_eren.md -> JSON kaydedildi
# ozgur_gokmen.md -> JSON kaydedildi
# pinar_ucar.md -> JSON kaydedildi
# rabia_cakir.md -> JSON kaydedildi
# rabia_celik.md -> JSON kaydedildi
# rabia_simsek.md -> JSON kaydedildi
# rabia_ucar.md -> JSON kaydedildi
# ramazan_acar.md -> JSON kaydedildi
# ramazan_ergin.md -> JSON kaydedildi
# ramazan_ucar.md -> JSON kaydedildi
# rukiye_karaca.md -> JSON kaydedildi
# rukiye_yuce.md -> JSON kaydedildi
# salih_karaca.md -> JSON kaydedildi
# salih_tas.md -> JSON kaydedildi
# salih_yildirim.md -> JSON kaydedildi
# sami_demir.md -> JSON kaydedildi
# sami_kaya.md -> JSON kaydedildi
# sami_kurt.md -> JSON kaydedildi
# sami_tas.md -> JSON kaydedildi
# sami_yilmaz.md -> JSON kaydedildi
# sebnem_aktas.md -> JSON kaydedildi
# sedef_aydin.md -> JSON kaydedildi
# sedef_sahin.md -> JSON kaydedildi
# selin_demir.md -> JSON kaydedildi
# selin_kaya.md -> JSON kaydedildi
# semra_baran.md -> JSON kaydedildi
# serap_tan.md -> JSON kaydedildi
# serdar_guler.md -> JSON kaydedildi
# serkan_celik.md -> JSON kaydedildi
# serpil_aksoy.md -> JSON kaydedildi
# serra_keskin.md -> JSON kaydedildi
# sevda_aktas.md -> JSON kaydedildi
# sevda_baran.md -> JSON kaydedildi
# sevda_yuce.md -> JSON kaydedildi
# sibel_cakir.md -> JSON kaydedildi
# sinan_gokmen.md -> JSON kaydedildi
# sinan_ozturk.md -> JSON kaydedildi
# suleyman_ermis.md -> JSON kaydedildi
# suna_celik.md -> JSON kaydedildi
# tamer_koc.md -> JSON kaydedildi
# taner_dogan.md -> JSON kaydedildi
# taner_toprak.md -> JSON kaydedildi
# tarik_karaca.md -> JSON kaydedildi
# tolga_eren.md -> JSON kaydedildi
# tolga_ergin.md -> JSON kaydedildi
# tolga_toprak.md -> JSON kaydedildi
# tuncay_acar.md -> JSON kaydedildi
# tuncay_karaca.md -> JSON kaydedildi
# ugur_sahin.md -> JSON kaydedildi
# veli_uzun.md -> JSON kaydedildi
# veli_yuce.md -> JSON kaydedildi
# vildan_kara.md -> JSON kaydedildi
# vildan_ozkan.md -> JSON kaydedildi
# vildan_sahin.md -> JSON kaydedildi
# vildan_tan.md -> JSON kaydedildi
# yeliz_celik.md -> JSON kaydedildi
# yeliz_gokmen.md -> JSON kaydedildi
# yeliz_toprak.md -> JSON kaydedildi
# yilmaz_aktas.md -> JSON kaydedildi
# yilmaz_aslan.md -> JSON kaydedildi
# yilmaz_kaya.md -> JSON kaydedildi
# yunus_altun.md -> JSON kaydedildi
# yunus_sezer.md -> JSON kaydedildi
# yusuf_avci.md -> JSON kaydedildi
# yusuf_uzun.md -> JSON kaydedildi
# yusuf_yildirim.md -> JSON kaydedildi
# zafer_bozkurt.md -> JSON kaydedildi
# zafer_gokmen.md -> JSON kaydedildi
# zafer_guler.md -> JSON kaydedildi
# zeki_bulut.md -> JSON kaydedildi
# zeki_kara.md -> JSON kaydedildi
# zeynep_kaplan.md -> JSON kaydedildi
# zeynep_polat.md -> JSON kaydedildi
